# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
s=pd.Series([10,20,30,40])
s=pd.Series(['mahnoor','christible', 'hiba', 'ayesha', 'fatimah', 'tehreem'])
s
# Out:
# 0       mahnoor
# 1    christible
# 2          hiba
# 3        ayesha
# 4       fatimah
# 5       tehreem
# dtype: object

# %%
data_of_python_class={
    "name":['mahnoor','christible', 'hiba', 'ayesha', 'fatimah', 'tehreem'],
    "age":[10, 20, 90, 18, 77,1000]
}



df =pd.DataFrame(data_of_python_class)
df
# Out:
#          name   age
# 0     mahnoor    10
# 1  christible    20
# 2        hiba    90
# 3      ayesha    18
# 4     fatimah    77
# 5     tehreem  1000

# %%
df.index
df.columns
# Out:
# Index(['name', 'age'], dtype='object')

# %%
df.index=[0, 1,2,3,4,5]
df.columns=['name', 'age']

# %%
pd.read_csv("quran.csv")
# Out:
#      code status  data.number              data.name data.englishName  \
# 0     200     OK            1   سُورَةُ ٱلْفَاتِحَةِ       Al-Faatiha
# 1     200     OK            6    سُورَةُ الأَنۡعَامِ        Al-An'aam
# 2     200     OK            7    سُورَةُ الأَعۡرَافِ        Al-A'raaf
# 3     200     OK           10        سُورَةُ يُونُسَ            Yunus
# 4     200     OK           11          سُورَةُ هُودٍ              Hud
# ..    ...    ...          ...                    ...              ...
# 109   200     OK           66   سُورَةُ التَّحۡرِيمِ        At-Tahrim
# 110   200     OK           76     سُورَةُ الإِنسَانِ        Al-Insaan
# 111   200     OK           98    سُورَةُ البَيِّنَةِ       Al-Bayyina
# 112   200     OK           99  سُورَةُ الزَّلۡزَلَةِ       Az-Zalzala
# 113   200     OK          110      سُورَةُ النَّصۡرِ          An-Nasr
#
#     data.englishNameTranslation  data.numberOfAyahs data.revelationType
# ...

# %%
pd.read_excel("quran.xlsx")
# Out:
#      code status  data.number              data.name data.englishName  \
# 0     200     OK            1   سُورَةُ ٱلْفَاتِحَةِ       Al-Faatiha
# 1     200     OK            6    سُورَةُ الأَنۡعَامِ        Al-An'aam
# 2     200     OK            7    سُورَةُ الأَعۡرَافِ        Al-A'raaf
# 3     200     OK           10        سُورَةُ يُونُسَ            Yunus
# 4     200     OK           11          سُورَةُ هُودٍ              Hud
# ..    ...    ...          ...                    ...              ...
# 109   200     OK           66   سُورَةُ التَّحۡرِيمِ        At-Tahrim
# 110   200     OK           76     سُورَةُ الإِنسَانِ        Al-Insaan
# 111   200     OK           98    سُورَةُ البَيِّنَةِ       Al-Bayyina
# 112   200     OK           99  سُورَةُ الزَّلۡزَلَةِ       Az-Zalzala
# 113   200     OK          110      سُورَةُ النَّصۡرِ          An-Nasr
#
#     data.englishNameTranslation  data.numberOfAyahs data.revelationType
# ...

# %%
pd.read_csv("https://raw.githubusercontent.com/SyedMuhammadArsalanShah/DataScienceCourse/refs/heads/master/00Datasets/CSV%20Datasets/mental_health_survey.csv")
# Out:
#                 Timestamp  Age  Gender         Country state self_employed  \
# 0     2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1     2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2     2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3     2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4     2014-08-27 11:30:22   31    Male   United States    TX           NaN
# ...                   ...  ...     ...             ...   ...           ...
# 1254  2015-09-12 11:17:21   26    male  United Kingdom   NaN            No
# 1255  2015-09-26 01:07:35   32    Male   United States    IL            No
# 1256  2015-11-07 12:36:58   34    male   United States    CA            No
# 1257  2015-11-30 21:25:06   46       f   United States    NC            No
# 1258  2016-02-01 23:04:31   25    Male   United States    IL            No
#
#      family_history treatment work_interfere    no_employees  ...  \
# ...

# %%
data=pd.read_json("https://api.alquran.cloud/v1/surah")
data

df=pd.json_normalize(data["data"])
df
# Out:
#      number                    name   englishName englishNameTranslation  \
# 0         1    سُورَةُ ٱلْفَاتِحَةِ    Al-Faatiha            The Opening
# 1         2      سُورَةُ البَقَرَةِ     Al-Baqara                The Cow
# 2         3  سُورَةُ آلِ عِمۡرَانَ  Aal-i-Imraan   The Family of Imraan
# 3         4      سُورَةُ النِّسَاءِ      An-Nisaa              The Women
# 4         5    سُورَةُ المَائـِدَةِ     Al-Maaida              The Table
# ..      ...                     ...           ...                    ...
# 109     110       سُورَةُ النَّصۡرِ       An-Nasr         Divine Support
# 110     111        سُورَةُ المَسَدِ      Al-Masad         The Palm Fibre
# 111     112     سُورَةُ الإِخۡلَاصِ    Al-Ikhlaas              Sincerity
# 112     113        سُورَةُ الفَلَقِ      Al-Falaq               The Dawn
# 113     114        سُورَةُ النَّاسِ       An-Naas                Mankind
#
#      numberOfAyahs revelationType
# 0                7         Meccan
# ...

# %%
df.head()
df.head(50)
df.tail(14)
df.info()
df.describe()
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114 entries, 0 to 113
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   number                  114 non-null    int64
#  1   name                    114 non-null    object
#  2   englishName             114 non-null    object
#  3   englishNameTranslation  114 non-null    object
#  4   numberOfAyahs           114 non-null    int64
#  5   revelationType          114 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 5.5+ KB
# (114, 6)

# %%
df["name"]
df[["name", "numberOfAyahs"]]
# Out:
#                        name  numberOfAyahs
# 0      سُورَةُ ٱلْفَاتِحَةِ              7
# 1        سُورَةُ البَقَرَةِ            286
# 2    سُورَةُ آلِ عِمۡرَانَ            200
# 3        سُورَةُ النِّسَاءِ            176
# 4      سُورَةُ المَائـِدَةِ            120
# ..                      ...            ...
# 109       سُورَةُ النَّصۡرِ              3
# 110        سُورَةُ المَسَدِ              5
# 111     سُورَةُ الإِخۡلَاصِ              4
# 112        سُورَةُ الفَلَقِ              5
# 113        سُورَةُ النَّاسِ              6
#
# [114 rows x 2 columns]

# %%
df.loc[0]
df.iloc[113]


df.loc[0,"name"]

df.loc[0,["name", "numberOfAyahs"]]


df.iloc[0:2]

df.iloc[0:,1:4]

# row , cols
df.iloc[0:2,0:3]
# Out:
#    number                  name englishName
# 0       1  سُورَةُ ٱلْفَاتِحَةِ  Al-Faatiha
# 1       2    سُورَةُ البَقَرَةِ   Al-Baqara

# %%
df.at[0, "name"]
df.iat[0,2]
# Out:
# 'Al-Faatiha'

# %%
df.query("numberOfAyahs > 100 and revelationType == 'Meccan'")
df[df["numberOfAyahs"]<50]
# Out:
#      number                  name englishName englishNameTranslation  \
# 0         1  سُورَةُ ٱلْفَاتِحَةِ  Al-Faatiha            The Opening
# 12       13     سُورَةُ الرَّعۡدِ     Ar-Ra'd            The Thunder
# 30       31     سُورَةُ لُقۡمَانَ      Luqman                 Luqman
# 31       32   سُورَةُ السَّجۡدَةِ    As-Sajda        The Prostration
# 34       35       سُورَةُ فَاطِرٍ      Faatir         The Originator
# ..      ...                   ...         ...                    ...
# 109     110     سُورَةُ النَّصۡرِ     An-Nasr         Divine Support
# 110     111      سُورَةُ المَسَدِ    Al-Masad         The Palm Fibre
# 111     112   سُورَةُ الإِخۡلَاصِ  Al-Ikhlaas              Sincerity
# 112     113      سُورَةُ الفَلَقِ    Al-Falaq               The Dawn
# 113     114      سُورَةُ النَّاسِ     An-Naas                Mankind
#
#      numberOfAyahs revelationType
# 0                7         Meccan
# 12              43        Medinan
# ...

# %%
df.isnull().sum()
df.dropna()
df.fillna(0)
df.duplicated()
df.drop_duplicates()
# Out:
#      number                    name   englishName englishNameTranslation  \
# 0         1    سُورَةُ ٱلْفَاتِحَةِ    Al-Faatiha            The Opening
# 1         2      سُورَةُ البَقَرَةِ     Al-Baqara                The Cow
# 2         3  سُورَةُ آلِ عِمۡرَانَ  Aal-i-Imraan   The Family of Imraan
# 3         4      سُورَةُ النِّسَاءِ      An-Nisaa              The Women
# 4         5    سُورَةُ المَائـِدَةِ     Al-Maaida              The Table
# ..      ...                     ...           ...                    ...
# 109     110       سُورَةُ النَّصۡرِ       An-Nasr         Divine Support
# 110     111        سُورَةُ المَسَدِ      Al-Masad         The Palm Fibre
# 111     112     سُورَةُ الإِخۡلَاصِ    Al-Ikhlaas              Sincerity
# 112     113        سُورَةُ الفَلَقِ      Al-Falaq               The Dawn
# 113     114        سُورَةُ النَّاسِ       An-Naas                Mankind
#
#      numberOfAyahs revelationType
# 0                7         Meccan
# ...

# %%
df["englishName"].str.upper()
# Out:
# 0        AL-FAATIHA
# 1         AL-BAQARA
# 2      AAL-I-IMRAAN
# 3          AN-NISAA
# 4         AL-MAAIDA
#            ...
# 109         AN-NASR
# 110        AL-MASAD
# 111      AL-IKHLAAS
# 112        AL-FALAQ
# 113         AN-NAAS
# Name: englishName, Length: 114, dtype: object
